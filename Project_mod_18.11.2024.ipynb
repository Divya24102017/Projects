# %%
#--Importing python libraries for data manipulation and analysis.
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#--Importing table1 of sheet1 data from an excel file into a Pandas DataFrame(df_Table1).
df_Table1 = pd.read_excel("D:\\Divya\Python Classes\\Project\\Project_18.11.2024\\Campaign data.xlsx")

# %%
#--Fetching out data's in table1.
df_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
#--Importing table2 of sheet2 data from an excel file into a Pandas DataFrame(df_Table2).
df_Table2 = pd.read_excel("D:\\Divya\Python Classes\\Project\\Project_18.11.2024\\Campaign data.xlsx", sheet_name = "Table 2")

# %%
#--Fetching out data's in table2.
df_Table2
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
#--Checking for the number of rows and columns in table1. 
df_Table1.shape
# Out:
# (123699, 7)

# %%
#--Checking for the duplicates in table1.
df_Table1[df_Table1.duplicated()]
# Out:
#              Date Data source      Campaign Media Type  \
# 80807  2021-03-29   Pinterest  shop at home    Display
# 80858  2021-03-29   Pinterest  shop at home    Display
# 80907  2021-03-29   Pinterest  shop at home    Display
# 80908  2021-03-29   Pinterest  shop at home    Display
# 80909  2021-03-29   Pinterest  shop at home    Display
# ...           ...         ...           ...        ...
# 122584 2021-09-27   Pinterest  shop at home    Display
# 122585 2021-09-27   Pinterest  shop at home    Display
# 122586 2021-09-27   Pinterest  shop at home    Display
# 122587 2021-09-27   Pinterest  shop at home    Display
# 122588 2021-09-27   Pinterest  shop at home    Display
#
#                               City       Metric   Value
# 80807                        Utica       Clicks    3.00
# 80858                        Utica       Clicks    3.00
# 80907                        Utica  Impressions  750.00
# 80908                        Utica   Media Cost    5.33
# ...

# %%
#--Removing the duplicate rows in table1.
df_Table1.drop_duplicates(inplace = True)

# %%
#--Checking for the number of rows and columns in table1 afetr removing the duplicates.
df_Table1.shape
# Out:
# (122629, 7)

# %%
#--Checking for the number of rows and columns in table2. 
df_Table2.shape
# Out:
# (58, 3)

# %%
#--Checking for the duplicates in table2.
df_Table2[df_Table2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Campaign, Message type, Model]
# Index: []

# %%
#--In table2 there is no duplicate data's, so dropping the duplicates step is not required here.

# %%
#--1.Find out the top 5 months in terms of impressions?

# %%
#--Step1.Converting the date format.
df_Table1['Date'] = pd.to_datetime(df_Table1['Date'])
df_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
#--Step2.Segregating day, month and year columns respectively.
df_Table1['Day'] = df_Table1['Date'].dt.day
df_Table1['month'] = df_Table1['Date'].dt.month
df_Table1['year'] = df_Table1['Date'].dt.year
df_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
#--Step3.Filtering 'Impressions' value from the 'Metric' column.
df1_Table1 = df_Table1[df_Table1['Metric'] == 'Impressions']
df1_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step4.Using groupby extracting data's of 'Impressions' value from the 'Metric' column for all the months and year.
df2_Table1 = (df1_Table1.groupby(['month','Metric','year'])['Value'].sum()).sort_values(ascending = False).reset_index()
df2_Table1
# Out:
#     month       Metric  year        Value
# 0       9  Impressions  2021  165961494.0
# 1      10  Impressions  2020  129386691.0
# 2       8  Impressions  2021  110579025.0
# 3       3  Impressions  2021  101719848.0
# 4       2  Impressions  2020   61351689.0
# 5       3  Impressions  2020   57768334.0
# 6      12  Impressions  2020   54048418.0
# 7       1  Impressions  2021   41756178.0
# 8       2  Impressions  2021   34320460.0
# 9       9  Impressions  2020   29477044.0
# 10     11  Impressions  2020   28514591.0
# 11      4  Impressions  2021   20774716.0
# 12      8  Impressions  2020    6720508.0
# 13      7  Impressions  2020    5341296.0
# 14      6  Impressions  2020     579534.0
# 15      5  Impressions  2021      17589.0
# 16      7  Impressions  2021      10358.0
# 17      4  Impressions  2020       9999.0
# 18      6  Impressions  2021       9154.0
# 19      5  Impressions  2020       8448.0
# 20      1  Impressions  2020         53.0
# ...

# %%
#--Step5.Extracting top 5 months in terms of'Impressions'.
df2_Table1.head(5)
# Out:
#    month       Metric  year        Value
# 0      9  Impressions  2021  165961494.0
# 1     10  Impressions  2020  129386691.0
# 2      8  Impressions  2021  110579025.0
# 3      3  Impressions  2021  101719848.0
# 4      2  Impressions  2020   61351689.0

# %%
#--2.Which model has maximum impressions?

# %%
#--Step1.Merging two tables using primary key.
dfmerge_table = pd.merge(df_Table1, df_Table2 , on ='Campaign')
dfmerge_table
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
#--Step2.Filtering 'Impressions' value from the 'Metric' column.
df3_Table1 = dfmerge_table[dfmerge_table['Metric'] == 'Impressions']
df3_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122614 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122617 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122620 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122623 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step3.Using groupby extracting data's of 'Impressions' value from the 'Metric' column for all the 'model'.
(df3_Table1.groupby(['Model','Metric'])['Value'].sum()).sort_values(ascending = False).reset_index()
# Out:
#          Model       Metric        Value
# 0   Pathfinder  Impressions  275832034.0
# 1       Armada  Impressions  175569709.0
# 2        Rogue  Impressions  132109157.0
# 3       Altima  Impressions   99823376.0
# 4        Kicks  Impressions   95929225.0
# 5       Sentra  Impressions   64176011.0
# 6  Multi-Model  Impressions    4915930.0

# %%
#--Step4.Extracting 'model' for maximum 'Impressions'.
(df3_Table1.groupby(['Model','Metric'])['Value'].sum()).sort_values(ascending = False).reset_index().head(1)
# Out:
#         Model       Metric        Value
# 0  Pathfinder  Impressions  275832034.0

# %%
#--3.Find out the top 3 campaigns in terms of impressions for every message type.

# %%
#--Step1.Merging two tables using primary key.
dfmerge1_table = pd.merge(df_Table1, df_Table2 , on ='Campaign')
dfmerge1_table
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
#--Step2.Filtering 'Impressions' value from the 'Metric' column.
df4_Table1 = dfmerge1_table[dfmerge1_table['Metric'] == 'Impressions']
df4_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122614 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122617 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122620 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122623 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step3.Extracting 'Campaign' value counts in terms of 'Impressions' for every message type using groupby.
df5_Table1 = df4_Table1.groupby(['Message type','Metric','Campaign'])['Value'].sum().reset_index()
df5_Table1
# Out:
#      Message type       Metric               Campaign        Value
# 0   Future Market  Impressions      Altima campaign 1   35863660.0
# 1   Future Market  Impressions      Altima campaign 2    7200627.0
# 2   Future Market  Impressions      Altima campaign 3   45451489.0
# 3   Future Market  Impressions      Altima campaign 4     380995.0
# 4   Future Market  Impressions      Altima campaign 5    1176593.0
# 5   Future Market  Impressions      Altima campaign 6    1533773.0
# 6   Future Market  Impressions       Kicks campaign 3   27167086.0
# 7   Future Market  Impressions       Kicks campaign 4   33664998.0
# 8   Future Market  Impressions       Kicks campaign 5    1981485.0
# 9   Future Market  Impressions       Kicks campaign 6   32993380.0
# 10  Future Market  Impressions       Rogue campaign 1   18925107.0
# 11  Future Market  Impressions       Rogue campaign 2   25647766.0
# 12  Future Market  Impressions       Rogue campaign 3    4774134.0
# ...

# %%
#--Step4.Sorting out the 'Value' column.
df6_Table1 = df5_Table1.sort_values(by = 'Value', ascending = False)
df6_Table1
# Out:
#      Message type       Metric               Campaign        Value
# 24    Near Market  Impressions      Armada campaign 2  118817195.0
# 30    Near Market  Impressions  Pathfinder campaign 2  115286607.0
# 34    Near Market  Impressions  Pathfinder campaign 6   51823574.0
# 29    Near Market  Impressions  Pathfinder campaign 1   48923126.0
# 2   Future Market  Impressions      Altima campaign 3   45451489.0
# 26    Near Market  Impressions      Armada campaign 4   37470993.0
# 0   Future Market  Impressions      Altima campaign 1   35863660.0
# 7   Future Market  Impressions       Kicks campaign 4   33664998.0
# 14  Future Market  Impressions       Rogue campaign 5   33448074.0
# 9   Future Market  Impressions       Kicks campaign 6   32993380.0
# 13  Future Market  Impressions       Rogue campaign 4   32510217.0
# 6   Future Market  Impressions       Kicks campaign 3   27167086.0
# 11  Future Market  Impressions       Rogue campaign 2   25647766.0
# ...

# %%
#--Step5.Extracting top 3 'Campaign' in terms of 'Impressions' for every message type.
df6_Table1.groupby(['Message type']).head(3).reset_index()
# Out:
#    index   Message type       Metric               Campaign        Value
# 0     24    Near Market  Impressions      Armada campaign 2  118817195.0
# 1     30    Near Market  Impressions  Pathfinder campaign 2  115286607.0
# 2     34    Near Market  Impressions  Pathfinder campaign 6   51823574.0
# 3      2  Future Market  Impressions      Altima campaign 3   45451489.0
# 4      0  Future Market  Impressions      Altima campaign 1   35863660.0
# 5      7  Future Market  Impressions       Kicks campaign 4   33664998.0

# %%
#--4.Does the campaign with maximum impressions also have maximum clicks?

# %%
#--Step1.Filtering 'Impressions' and 'Clicks' value from the 'Metric' column.
df6_Table1 = df_Table1[df_Table1['Metric'].isin(['Impressions', 'Clicks'])]
df6_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 5      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123692 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step2.Using group by to extract the 'Campaign' with maximum 'Impressions' and 'Clicks'.
df7_Table1 = (df6_Table1.groupby(['Metric','Campaign'])['Value'].sum()).sort_values(ascending = False).reset_index()
df7_Table1
# Out:
#           Metric               Campaign        Value
# 0    Impressions      Armada campaign 2  118817195.0
# 1    Impressions  Pathfinder campaign 2  115286607.0
# 2    Impressions  Pathfinder campaign 6   51823574.0
# 3    Impressions  Pathfinder campaign 1   48923126.0
# 4    Impressions      Altima campaign 3   45451489.0
# ..           ...                    ...          ...
# 111       Clicks     Sentra campaign 13        498.0
# 112       Clicks     Sentra campaign 10        411.0
# 113       Clicks       Kicks campaign 1         25.0
# 114       Clicks       Kicks campaign 2          7.0
# 115       Clicks      Armada campaign 1          0.0
#
# [116 rows x 3 columns]

# %%
#--Step3.Extracting 'Campaign' with maximum 'Impressions' and 'Campaign' with maximum 'Clicks'.
     #--No,campaign with maximum impressions also have maximum clicks.
df7_Table1.groupby(['Metric']).head(1).reset_index()
# Out:
#    index       Metric           Campaign        Value
# 0      0  Impressions  Armada campaign 2  118817195.0
# 1     54       Clicks  Armada campaign 2     241938.0

# %%
#--5.Find out the top 3 campaigns in terms of CPM (CPM stands for cost per mile which means cost per 1000 impressions. 
#--CPM = total media cost/total impressions * 1000)

# %%
#--Step1.Filtering 'Impressions' value from the 'Metric' column.
df8_Table1 = df_Table1[df_Table1['Metric'] == 'Impressions']
df8_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123684 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123687 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step2.Creating a new column as 'Total Impressions' in terms of 'Impressions' and 'Campaign'.
df9_Table1 = df8_Table1.groupby(['Campaign','Metric'])['Value'].sum().reset_index(name='Total Impressions')
df9_Table1
# Out:
#                  Campaign       Metric  Total Impressions
# 0       Altima campaign 1  Impressions         35863660.0
# 1       Altima campaign 2  Impressions          7200627.0
# 2       Altima campaign 3  Impressions         45451489.0
# 3       Altima campaign 4  Impressions           380995.0
# 4       Altima campaign 5  Impressions          1176593.0
# 5       Altima campaign 6  Impressions          1533773.0
# 6       Altima campaign 7  Impressions          2043425.0
# 7       Altima campaign 8  Impressions          6172814.0
# 8       Armada campaign 1  Impressions          1799471.0
# 9       Armada campaign 2  Impressions        118817195.0
# 10      Armada campaign 3  Impressions         17482050.0
# 11      Armada campaign 4  Impressions         37470993.0
# 12       Kicks campaign 1  Impressions           120791.0
# 13       Kicks campaign 2  Impressions             1485.0
# 14       Kicks campaign 3  Impressions         27167086.0
# ...

# %%
#--Step3.Sorting the 'Total Impressions' values.
df10_Table1 = df9_Table1.sort_values(by='Total Impressions', ascending=False)
df10_Table1
# Out:
#                  Campaign       Metric  Total Impressions
# 9       Armada campaign 2  Impressions        118817195.0
# 19  Pathfinder campaign 2  Impressions        115286607.0
# 23  Pathfinder campaign 6  Impressions         51823574.0
# 18  Pathfinder campaign 1  Impressions         48923126.0
# 2       Altima campaign 3  Impressions         45451489.0
# 11      Armada campaign 4  Impressions         37470993.0
# 0       Altima campaign 1  Impressions         35863660.0
# 15       Kicks campaign 4  Impressions         33664998.0
# 30       Rogue campaign 5  Impressions         33448074.0
# 17       Kicks campaign 6  Impressions         32993380.0
# 29       Rogue campaign 4  Impressions         32510217.0
# 14       Kicks campaign 3  Impressions         27167086.0
# 27       Rogue campaign 2  Impressions         25647766.0
# 26       Rogue campaign 1  Impressions         18925107.0
# 10      Armada campaign 3  Impressions         17482050.0
# ...

# %%
#--Step4.Filtering 'Media Cost' value from the 'Metric' column.
df11_Table1 = df_Table1[df_Table1['Metric'] == 'Media Cost']
df11_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123685 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123688 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123691 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value  Day  month  year
# 1               Colorado Springs-Pueblo  Media Cost    0.00   30     12  2019
# ...

# %%
#--Step5.Creating a new column as 'Total Media Cost' in terms of 'Media Cost' and 'Campaign'.
df12_Table1 = df11_Table1.groupby(['Campaign','Metric'])['Value'].sum().reset_index(name='Total Media Cost')
df12_Table1
# Out:
#                  Campaign      Metric  Total Media Cost
# 0       Altima campaign 1  Media Cost         489477.29
# 1       Altima campaign 2  Media Cost          74693.85
# 2       Altima campaign 3  Media Cost         376369.35
# 3       Altima campaign 4  Media Cost           6000.05
# 4       Altima campaign 5  Media Cost          18391.45
# 5       Altima campaign 6  Media Cost          13033.96
# 6       Altima campaign 7  Media Cost          19614.55
# 7       Altima campaign 8  Media Cost          47398.70
# 8       Armada campaign 1  Media Cost           8210.77
# 9       Armada campaign 2  Media Cost         698093.58
# 10      Armada campaign 3  Media Cost         145040.71
# 11      Armada campaign 4  Media Cost         298919.40
# 12       Kicks campaign 1  Media Cost              0.00
# 13       Kicks campaign 2  Media Cost              0.00
# 14       Kicks campaign 3  Media Cost         181003.85
# 15       Kicks campaign 4  Media Cost         181523.37
# ...

# %%
#--Step6.Sorting the 'Total Media Cost' values.
df13_Table1 = df12_Table1.sort_values(by='Total Media Cost', ascending=False)
df13_Table1
# Out:
#                  Campaign      Metric  Total Media Cost
# 23  Pathfinder campaign 6  Media Cost         797639.63
# 9       Armada campaign 2  Media Cost         698093.58
# 19  Pathfinder campaign 2  Media Cost         689604.29
# 0       Altima campaign 1  Media Cost         489477.29
# 29       Rogue campaign 4  Media Cost         484928.76
# 2       Altima campaign 3  Media Cost         376369.35
# 17       Kicks campaign 6  Media Cost         370962.96
# 22  Pathfinder campaign 5  Media Cost         316442.90
# 24  Pathfinder campaign 7  Media Cost         304427.70
# 11      Armada campaign 4  Media Cost         298919.40
# 25  Pathfinder campaign 8  Media Cost         292833.90
# 18  Pathfinder campaign 1  Media Cost         261944.37
# 27       Rogue campaign 2  Media Cost         244984.76
# 30       Rogue campaign 5  Media Cost         224408.94
# 26       Rogue campaign 1  Media Cost         218075.42
# 15       Kicks campaign 4  Media Cost         181523.37
# ...

# %%
#--Step7.Merging 'Total Impressions' and 'Total Media Cost' in terms of 'Campaign'.
dfmerge2_table = pd.merge(df10_Table1 , df13_Table1 , on = 'Campaign')
dfmerge2_table
# Out:
#                  Campaign     Metric_x  Total Impressions    Metric_y  \
# 0       Armada campaign 2  Impressions        118817195.0  Media Cost
# 1   Pathfinder campaign 2  Impressions        115286607.0  Media Cost
# 2   Pathfinder campaign 6  Impressions         51823574.0  Media Cost
# 3   Pathfinder campaign 1  Impressions         48923126.0  Media Cost
# 4       Altima campaign 3  Impressions         45451489.0  Media Cost
# 5       Armada campaign 4  Impressions         37470993.0  Media Cost
# 6       Altima campaign 1  Impressions         35863660.0  Media Cost
# 7        Kicks campaign 4  Impressions         33664998.0  Media Cost
# 8        Rogue campaign 5  Impressions         33448074.0  Media Cost
# 9        Kicks campaign 6  Impressions         32993380.0  Media Cost
# 10       Rogue campaign 4  Impressions         32510217.0  Media Cost
# 11       Kicks campaign 3  Impressions         27167086.0  Media Cost
# ...

# %%
#--Step8.Creating a new column as 'CPM' in terms 'Campaign'.
dfmerge2_table['CPM'] = (dfmerge2_table['Total Media Cost'] / dfmerge2_table['Total Impressions']) * 1000

# %%
#--Step9.Filtering top 3 'Campaign' in terms of 'CPM'. 
dfmerge2_table.sort_values(by = 'CPM', ascending = False).head(3)
# Out:
#                  Campaign     Metric_x  Total Impressions    Metric_y  \
# 28  Pathfinder campaign 3  Impressions          3977697.0  Media Cost
# 15  Pathfinder campaign 5  Impressions         17292561.0  Media Cost
# 17  Pathfinder campaign 7  Impressions         16733721.0  Media Cost
#
#     Total Media Cost        CPM
# 28          73584.37  18.499240
# 15         316442.90  18.299366
# 17         304427.70  18.192469

# %%
#--6.What is the monthly average media cost for different media types?

# %%
#--Step1.Filtering 'Media Cost' value from the 'Metric' column.
df14_Table1 = df_Table1[df_Table1['Metric'] == 'Media Cost']
df14_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 123685 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123688 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123691 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value  Day  month  year
# 1               Colorado Springs-Pueblo  Media Cost    0.00   30     12  2019
# ...

# %%
#--Step2.Extracting monthly average 'Media Cost' for different 'Media Type'.
df14_Table1.groupby(['month','year','Metric','Media Type'])['Value'].mean().reset_index()
# Out:
#     month  year      Metric    Media Type       Value
# 0       1  2020  Media Cost       Display    0.000000
# 1       1  2020  Media Cost  Online Video    0.000000
# 2       1  2021  Media Cost       Display    0.000000
# 3       1  2021  Media Cost  Online Video  129.927345
# 4       2  2020  Media Cost       Display  424.566390
# 5       2  2020  Media Cost  Online Video    0.000000
# 6       2  2021  Media Cost       Display    0.000000
# 7       2  2021  Media Cost  Online Video  180.083354
# 8       3  2020  Media Cost       Display  411.136057
# 9       3  2020  Media Cost  Online Video    8.695333
# 10      3  2021  Media Cost       Display    3.893718
# 11      3  2021  Media Cost  Online Video  186.902184
# 12      4  2020  Media Cost       Display    0.000000
# 13      4  2020  Media Cost  Online Video    0.000000
# 14      4  2021  Media Cost       Display   75.663433
# 15      4  2021  Media Cost  Online Video  172.286245
# ...

# %%
#--Step2.Extracting 'Media Cost' in terms of 'Media Type'.
df14_Taable1 = (df14_Table1.groupby(['month','year','Metric','Media Type'])['Value'].mean()).sort_values(ascending = False).reset_index()
df14_Taable1
# Out:
#     month  year      Metric    Media Type       Value
# 0       9  2020  Media Cost  Online Video  644.141190
# 1       2  2020  Media Cost       Display  424.566390
# 2       3  2020  Media Cost       Display  411.136057
# 3       9  2021  Media Cost  Online Video  281.996328
# 4       8  2021  Media Cost  Online Video  259.055211
# 5      10  2020  Media Cost  Online Video  250.820020
# 6      12  2020  Media Cost  Online Video  238.508465
# 7       9  2021  Media Cost       Display  211.265498
# 8       3  2021  Media Cost  Online Video  186.902184
# 9       2  2021  Media Cost  Online Video  180.083354
# 10      4  2021  Media Cost  Online Video  172.286245
# 11     11  2020  Media Cost  Online Video  148.412704
# 12      1  2021  Media Cost  Online Video  129.927345
# 13      8  2020  Media Cost  Online Video   80.534931
# 14      4  2021  Media Cost       Display   75.663433
# 15      7  2020  Media Cost  Online Video   26.610211
# ...

# %%
#--Step3.Extracting monthly average 'Media Cost' for different 'Media Type'.
df14_Taable1.groupby(['Media Type']).head(1).reset_index()
# Out:
#    index  month  year      Metric    Media Type      Value
# 0      0      9  2020  Media Cost  Online Video  644.14119
# 1      1      2  2020  Media Cost       Display  424.56639

# %%
#--7.Which media type is more expensive in terms of CPM?

# %%
#--Step1.Merging two tables using primary key.
dfmerge3_table = pd.merge(df_Table1, df_Table2 , on ='Campaign')
dfmerge3_table
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122625 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122628 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.00   30     12
# ...

# %%
#--Step2.Checking for the unique values in 'Media Type'.
dfmerge3_table['Media Type'].unique()
# Out:
# array(['Display', 'Online Video'], dtype=object)

# %%
#--Step3.Filtering 'Media Cost' value from the 'Metric' column.
df15_Table1 = dfmerge3_table[dfmerge3_table['Metric'] == 'Media Cost']
df15_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# 7      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 10     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 13     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122615 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122618 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122621 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122624 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122627 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City      Metric   Value  Day  month  year  \
# 1               Colorado Springs-Pueblo  Media Cost    0.00   30     12  2019
# ...

# %%
#--Step4.Creating a new column as 'Total Media Cost' in terms of 'Media Type'.
df16_Table1 = df15_Table1.groupby(['Media Type','Metric'])['Value'].sum().reset_index(name='Total Media Cost')
df16_Table1
# Out:
#      Media Type      Metric  Total Media Cost
# 0       Display  Media Cost        1017789.55
# 1  Online Video  Media Cost        6836809.63

# %%
#--Step5.Filtering 'Impressions' value from the 'Metric' column.
df17_Table1 = dfmerge3_table[dfmerge3_table['Metric'] == 'Impressions']
df17_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 6      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 9      2019-12-30   Pinterest       Kicks campaign 1  Online Video
# 12     2019-12-30   Pinterest       Kicks campaign 1  Online Video
# ...           ...         ...                    ...           ...
# 122614 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122617 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122620 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122623 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 122626 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric    Value  Day  month  \
# 0               Colorado Springs-Pueblo  Impressions      1.0   30     12
# ...

# %%
#--Step6.Creating a new column as 'Total Impressions' in terms of 'Media Type'.
df18_Table1 = df17_Table1.groupby(['Media Type','Metric'])['Value'].sum().reset_index(name='Total Impressions')
df18_Table1
# Out:
#      Media Type       Metric  Total Impressions
# 0       Display  Impressions        174091539.0
# 1  Online Video  Impressions        674263903.0

# %%
#--Step7.Merging 'Total Impressions' and 'Total Media Cost' in terms of 'Media Type'.
dfmerge4_table = pd.merge(df16_Table1 , df18_Table1 , on = 'Media Type')
dfmerge4_table
# Out:
#      Media Type    Metric_x  Total Media Cost     Metric_y  Total Impressions
# 0       Display  Media Cost        1017789.55  Impressions        174091539.0
# 1  Online Video  Media Cost        6836809.63  Impressions        674263903.0

# %%
#--Step8.Creating a new column as 'CPM' in terms 'Media Type'.
dfmerge4_table['CPM'] = (dfmerge4_table['Total Media Cost'] / dfmerge4_table['Total Impressions']) * 1000
dfmerge4_table
# Out:
#      Media Type    Metric_x  Total Media Cost     Metric_y  Total Impressions  \
# 0       Display  Media Cost        1017789.55  Impressions        174091539.0
# 1  Online Video  Media Cost        6836809.63  Impressions        674263903.0
#
#          CPM
# 0   5.846290
# 1  10.139664

# %%
#--Step9.Sorting the 'CPM' values to find out the expensive 'Media Type'.
dfmerge4_table.sort_values(by='CPM', ascending=False)[:1]
# Out:
#      Media Type    Metric_x  Total Media Cost     Metric_y  Total Impressions  \
# 1  Online Video  Media Cost        6836809.63  Impressions        674263903.0
#
#          CPM
# 1  10.139664
