# %% [markdown]
# Analysis of the excel file

# %%
#--Importing python libraries for data manipulation and analysis.
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Analysis of Table1

# %%
#--Importing table1 of sheet1 data from an excel file into a Pandas DataFrame(df_Table1).
df_Table1 = pd.read_excel("D:\\Divya\\Python Classes\\Project\\Campaign data.xlsx")
df_Table1
# Out:
#              Date Data source               Campaign    Media Type  \
# 0      2019-12-30   Pinterest       Kicks campaign 2       Display
# 1      2019-12-30   Pinterest       Kicks campaign 2       Display
# 2      2019-12-30   Pinterest       Kicks campaign 2       Display
# 3      2019-12-30   Pinterest       Kicks campaign 2       Display
# 4      2019-12-30   Pinterest       Kicks campaign 2       Display
# ...           ...         ...                    ...           ...
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 0               Colorado Springs-Pueblo  Impressions      1.00
# ...

# %%
#--Checking for the number of rows and columns in table1.
df_Table1.shape
# Out:
# (123699, 7)

# %%
#--Checking for the number of rows in the table1 by using index.
df_Table1.shape[0]
# Out:
# 123699

# %%
#--Checking for the number of columns in the table1 by using index.
df_Table1.shape[1]
# Out:
# 7

# %%
#--Extracting top 5 rows in table1.{head() - by default it shows the first 5 rows.}
df_Table1.head()
# Out:
#         Date Data source          Campaign Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2    Display
# 1 2019-12-30   Pinterest  Kicks campaign 2    Display
# 2 2019-12-30   Pinterest  Kicks campaign 2    Display
# 3 2019-12-30   Pinterest  Kicks campaign 2    Display
# 4 2019-12-30   Pinterest  Kicks campaign 2    Display
#
#                        City       Metric  Value
# 0   Colorado Springs-Pueblo  Impressions    1.0
# 1   Colorado Springs-Pueblo   Media Cost    0.0
# 2   Colorado Springs-Pueblo       Clicks    0.0
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0

# %%
#--Extracting top 8 rows in table1.
df_Table1.head(8)
# Out:
#         Date Data source          Campaign    Media Type  \
# 0 2019-12-30   Pinterest  Kicks campaign 2       Display
# 1 2019-12-30   Pinterest  Kicks campaign 2       Display
# 2 2019-12-30   Pinterest  Kicks campaign 2       Display
# 3 2019-12-30   Pinterest  Kicks campaign 2       Display
# 4 2019-12-30   Pinterest  Kicks campaign 2       Display
# 5 2019-12-30   Pinterest  Kicks campaign 2       Display
# 6 2019-12-30   Pinterest  Kicks campaign 1  Online Video
# 7 2019-12-30   Pinterest  Kicks campaign 1  Online Video
#
#                        City       Metric  Value
# 0   Colorado Springs-Pueblo  Impressions    1.0
# 1   Colorado Springs-Pueblo   Media Cost    0.0
# 2   Colorado Springs-Pueblo       Clicks    0.0
# 3  Sacramnto-Stkton-Modesto  Impressions    1.0
# 4  Sacramnto-Stkton-Modesto   Media Cost    0.0
# 5  Sacramnto-Stkton-Modesto       Clicks    0.0
# 6                  New York  Impressions    2.0
# 7                  New York   Media Cost    0.0

# %%
#--Extracting last 5 rows in table1.{tail() - by default it shows the last 5 rows.}
df_Table1.tail()
# Out:
#              Date Data source               Campaign    Media Type  \
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 123694  Sacramento - Stockton - Modesto   Media Cost    136.94
# 123695  Sacramento - Stockton - Modesto       Clicks     81.00
# 123696               Dallas - Ft. Worth  Impressions  16579.00
# 123697               Dallas - Ft. Worth   Media Cost    297.78
# 123698               Dallas - Ft. Worth       Clicks    128.00

# %%
#--Extracting last 9 rows in table1.
df_Table1.tail(9)
# Out:
#              Date Data source               Campaign    Media Type  \
# 123690 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123691 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123692 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123693 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123694 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123695 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123696 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123697 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
# 123698 2021-09-30    Snapchat  Pathfinder campaign 7  Online Video
#
#                                    City       Metric     Value
# 123690                 Seattle - Tacoma  Impressions  11191.00
# 123691                 Seattle - Tacoma   Media Cost    201.02
# 123692                 Seattle - Tacoma       Clicks    102.00
# ...

# %%
#--Extracting one random row in table1.{sample() - by default it shows the one random row.}
df_Table1.sample()
# Out:
#             Date Data source               Campaign    Media Type  \
# 99341 2021-08-19    Snapchat  Pathfinder campaign 7  Online Video
#
#                City  Metric  Value
# 99341  Philadelphia  Clicks   71.0

# %%
#--Extracting seven random rows in table1.
df_Table1.sample(7)
# Out:
#             Date Data source               Campaign    Media Type  \
# 82122 2021-04-05   Pinterest      Armada campaign 3  Online Video
# 2608  2020-02-24   Pinterest      Armada campaign 2       Display
# 86384 2021-05-10   Pinterest      Altima campaign 3  Online Video
# 15937 2020-08-10    Snapchat      Sentra campaign 3  Online Video
# 84231 2021-04-12   Pinterest           shop at home       Display
# 90320 2021-07-19   Pinterest       Kicks campaign 3       Display
# 92518 2021-08-03    Snapchat  Pathfinder campaign 7  Online Video
#
#                                        City       Metric     Value
# 82122                                 Omaha  Impressions  55621.00
# 2608                Grand Junction-Montrose   Media Cost     96.02
# 86384                  Albuquerque-Santa Fe       Clicks      0.00
# 15937  Birmingham (anniston And Tuscaloosa)   Media Cost     23.38
# 84231                Traverse City-Cadillac  Impressions  16866.00
# ...

# %%
#--Extracting all the columns name in table1.
df_Table1.columns
# Out:
# Index(['Date', 'Data source', 'Campaign', 'Media Type', 'City', 'Metric',
#        'Value'],
#       dtype='object')

# %%
#--Extracting all the data types in table1.
df_Table1.dtypes
# Out:
# Date           datetime64[ns]
# Data source            object
# Campaign               object
# Media Type             object
# City                   object
# Metric                 object
# Value                 float64
# dtype: object

# %%
#--Extracting all the index in table1.
df_Table1.index
# Out:
# RangeIndex(start=0, stop=123699, step=1)

# %%
#--Extracting summary in table1.
df_Table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123699 entries, 0 to 123698
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Date         123699 non-null  datetime64[ns]
#  1   Data source  123699 non-null  object
#  2   Campaign     123699 non-null  object
#  3   Media Type   123699 non-null  object
#  4   City         123699 non-null  object
#  5   Metric       123699 non-null  object
#  6   Value        123699 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 6.6+ MB

# %%
#--Extracting number of non-null counts for each column in table1.
df_Table1.count()
# Out:
# Date           123699
# Data source    123699
# Campaign       123699
# Media Type     123699
# City           123699
# Metric         123699
# Value          123699
# dtype: int64

# %%
#--Extracting summary statistics for numerical columns in table1.
df_Table1.describe()
# Out:
#                                 Date         Value
# count                         123699  1.236990e+05
# mean   2021-02-09 21:36:27.868940032  6.973219e+03
# min              2019-12-30 00:00:00  0.000000e+00
# 25%              2020-10-21 00:00:00  6.000000e+00
# 50%              2021-02-01 00:00:00  7.536000e+01
# 75%              2021-08-04 00:00:00  1.144900e+03
# max              2021-09-30 00:00:00  1.627800e+06
# std                              NaN  3.400261e+04

# %%
#--Extracting summary statistics for numerical and categorical columns in table1.{But it is especially useful for numerical columns.}
df_Table1.describe(include = 'all')
# Out:
#                                  Date Data source           Campaign  \
# count                          123699      123699             123699
# unique                            NaN           2                 58
# top                               NaN   Pinterest  Armada campaign 2
# freq                              NaN       66945              13392
# mean    2021-02-09 21:36:27.868940032         NaN                NaN
# min               2019-12-30 00:00:00         NaN                NaN
# 25%               2020-10-21 00:00:00         NaN                NaN
# 50%               2021-02-01 00:00:00         NaN                NaN
# 75%               2021-08-04 00:00:00         NaN                NaN
# max               2021-09-30 00:00:00         NaN                NaN
# std                               NaN         NaN                NaN
#
#           Media Type      City       Metric         Value
# count         123699    123699       123699  1.236990e+05
# ...

# %%
#--Checking for the duplicates in table1.
df_Table1.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 123694    False
# 123695    False
# 123696    False
# 123697    False
# 123698    False
# Length: 123699, dtype: bool

# %%
#--Extracting the duplicate rows in table1.
df_Table1[df_Table1.duplicated()]
# Out:
#              Date Data source      Campaign Media Type  \
# 80807  2021-03-29   Pinterest  shop at home    Display
# 80858  2021-03-29   Pinterest  shop at home    Display
# 80907  2021-03-29   Pinterest  shop at home    Display
# 80908  2021-03-29   Pinterest  shop at home    Display
# 80909  2021-03-29   Pinterest  shop at home    Display
# ...           ...         ...           ...        ...
# 122584 2021-09-27   Pinterest  shop at home    Display
# 122585 2021-09-27   Pinterest  shop at home    Display
# 122586 2021-09-27   Pinterest  shop at home    Display
# 122587 2021-09-27   Pinterest  shop at home    Display
# 122588 2021-09-27   Pinterest  shop at home    Display
#
#                               City       Metric   Value
# 80807                        Utica       Clicks    3.00
# 80858                        Utica       Clicks    3.00
# 80907                        Utica  Impressions  750.00
# 80908                        Utica   Media Cost    5.33
# ...

# %%
#--Removing the duplicate rows in table1.
df_Table1.drop_duplicates(inplace = True)

# %%
#--Extracting the null counts for all the columns in table1.
df_Table1.isnull().sum()
# Out:
# Date           0
# Data source    0
# Campaign       0
# Media Type     0
# City           0
# Metric         0
# Value          0
# dtype: int64

# %%
#--Extracting count of how many times each unique value appears in a specific column in table1.
for i in df_Table1.columns:
    print(i)
    print("__________________")
    print("__________________")
    print(df_Table1[i].value_counts())
    print("__________________")
# Out:
# Date
# __________________
# __________________
# Date
# 2021-09-27    3813
# 2020-10-26    3075
# 2020-10-19    3036
# 2020-10-12    2952
# 2021-09-20    2537
#               ...
# 2020-01-06      24
# 2020-01-27      21
# 2019-12-30      21
# 2020-01-20      12
# 2020-01-13      12
# Name: count, Length: 332, dtype: int64
# __________________
# Data source
# __________________
# __________________
# Data source
# Pinterest    65875
# Snapchat     56754
# Name: count, dtype: int64
# __________________
# Campaign
# __________________
# __________________
# Campaign
# Armada campaign 2        13392
# Rogue campaign 4          6030
# Pathfinder campaign 2     5670
# Altima campaign 3         5484
# Armada campaign 4         5400
# Rogue campaign 2          4923
# Rogue campaign 5          4560
# Pathfinder campaign 7     4332
# Pathfinder campaign 8     4302
# Pathfinder campaign 6     4254
# Pathfinder campaign 5     4254
# Sentra campaign 3         4209
# ...

# %%
#--Extracting the minimum value in the Value column in table1.
df_Table1['Value'].min()
# Out:
# 0.0

# %%
#--Extracting the maximum value in the Value column in table1.
df_Table1['Value'].max()
# Out:
# 1627800.0

# %%
#--Extracting number of non-null counts for Value column in table1.
df_Table1['Value'].count()
# Out:
# 122629

# %%
#--Extracting count of how many times each unique value appears in a Value column in table1.
df_Table1['Value'].value_counts()
# Out:
# Value
# 0.00        17080
# 1.00         3437
# 2.00         2449
# 3.00         1718
# 4.00         1406
#             ...
# 37290.00        1
# 11308.00        1
# 52.79           1
# 10822.00        1
# 297.78          1
# Name: count, Length: 43408, dtype: int64

# %%
#--Extracting summary statistics for Value column in table1.
df_Table1['Value'].describe()
# Out:
# count    1.226290e+05
# mean     6.999154e+03
# std      3.411575e+04
# min      0.000000e+00
# 25%      6.340000e+00
# 50%      7.600000e+01
# 75%      1.156000e+03
# max      1.627800e+06
# Name: Value, dtype: float64

# %%
#--Extracting unique values for Value column in table1.
df_Table1['Value'].unique()
# Out:
# array([1.0000e+00, 0.0000e+00, 2.0000e+00, ..., 1.4397e+04, 1.1191e+04,
#        2.9778e+02])

# %%
#--Extracting number of unique values for Value column in table1.
df_Table1['Value'].nunique()
# Out:
# 43408

# %%
#--Saving table1 to a excel file at the specified location on my system.
df_Table1.to_excel("D:\\Divya\\Python Classes\\Test Files\\Campaign_details1.xlsx")

# %%
Analysis of Table2

# %%
#--Importing table2 of sheet2 data from an excel file into a Pandas DataFrame(df_Table2).
df_Table2 = pd.read_excel("D:\\Divya\\Python Classes\\Project\\Campaign data.xlsx", sheet_name = "Table 2")
df_Table2
# Out:
#                  Campaign   Message type        Model
# 0       Sentra campaign 2  Future Market       Sentra
# 1       Sentra campaign 4  Future Market       Sentra
# 2       Sentra campaign 3  Future Market       Sentra
# 3       Sentra campaign 1  Future Market       Sentra
# 4       Altima campaign 1  Future Market       Altima
# 5       Altima campaign 5  Future Market       Altima
# 6       Altima campaign 4  Future Market       Altima
# 7       Altima campaign 6  Future Market       Altima
# 8        Kicks campaign 6  Future Market        Kicks
# 9        Kicks campaign 5  Future Market        Kicks
# 10       Rogue campaign 1  Future Market        Rogue
# 11       Rogue campaign 3  Future Market        Rogue
# 12       Rogue pre launch  Future Market        Rogue
# 13       Rogue campaign 5  Future Market        Rogue
# 14       Rogue campaign 4  Future Market        Rogue
# 15  Pathfinder campaign 3    Near Market   Pathfinder
# ...

# %%
#--Checking for the number of rows and columns in table2.
df_Table2.shape
# Out:
# (58, 3)

# %%
#--Checking for the number of rows in table2 by using index.
df_Table2.shape[0]
# Out:
# 58

# %%
#--Checking for the number of columns in table2 by using index.
df_Table2.shape[1]
# Out:
# 3

# %%
#--Extracting top 5 rows in table2.{head() - by default it shows the first 5 rows.}
df_Table2.head()
# Out:
#             Campaign   Message type   Model
# 0  Sentra campaign 2  Future Market  Sentra
# 1  Sentra campaign 4  Future Market  Sentra
# 2  Sentra campaign 3  Future Market  Sentra
# 3  Sentra campaign 1  Future Market  Sentra
# 4  Altima campaign 1  Future Market  Altima

# %%
#--Extracting top 7 rows in table2.
df_Table2.head(7)
# Out:
#             Campaign   Message type   Model
# 0  Sentra campaign 2  Future Market  Sentra
# 1  Sentra campaign 4  Future Market  Sentra
# 2  Sentra campaign 3  Future Market  Sentra
# 3  Sentra campaign 1  Future Market  Sentra
# 4  Altima campaign 1  Future Market  Altima
# 5  Altima campaign 5  Future Market  Altima
# 6  Altima campaign 4  Future Market  Altima

# %%
#--Extracting last 5 rows in table2.{tail() - by default it shows the last 5 rows.}
df_Table2.tail()
# Out:
#               Campaign Message type   Model
# 53   Sentra campaign 8  Near Market  Sentra
# 54  Sentra campaign 10  Near Market  Sentra
# 55  Sentra campaign 24  Near Market  Sentra
# 56  Sentra campaign 16  Near Market  Sentra
# 57  Sentra campaign 17  Near Market  Sentra

# %%
#--Extracting last 3 rows in table2.
df_Table2.tail(3)
# Out:
#               Campaign Message type   Model
# 55  Sentra campaign 24  Near Market  Sentra
# 56  Sentra campaign 16  Near Market  Sentra
# 57  Sentra campaign 17  Near Market  Sentra

# %%
#--Extracting one random row in table2.{sample() - by default it shows the one random row.}
df_Table2.sample()
# Out:
#               Campaign Message type   Model
# 39  Sentra campaign 20  Near Market  Sentra

# %%
#--Extracting eight random rows in table2.
df_Table2.sample(8)
# Out:
#                  Campaign   Message type       Model
# 14       Rogue campaign 4  Future Market       Rogue
# 35      Armada campaign 4    Near Market      Armada
# 42      Sentra campaign 7    Near Market      Sentra
# 9        Kicks campaign 5  Future Market       Kicks
# 18  Pathfinder campaign 5    Near Market  Pathfinder
# 40     Sentra campaign 21    Near Market      Sentra
# 27       Kicks campaign 4  Future Market       Kicks
# 7       Altima campaign 6  Future Market      Altima

# %%
#--Extracting all the columns name in table2.
df_Table2.columns
# Out:
# Index(['Campaign', 'Message type', 'Model'], dtype='object')

# %%
#--Extracting all the data types in table2.
df_Table2.dtypes
# Out:
# Campaign        object
# Message type    object
# Model           object
# dtype: object

# %%
#--Extracting all the index in table2.
df_Table2.index
# Out:
# RangeIndex(start=0, stop=58, step=1)

# %%
#--Extracting summary in table2.
df_Table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Campaign      58 non-null     object
#  1   Message type  58 non-null     object
#  2   Model         58 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
#--Extracting number of non-null counts for each column in table2.
df_Table2.count()
# Out:
# Campaign        58
# Message type    58
# Model           58
# dtype: int64

# %%
#--Extracting summary statistics for numerical columns in table2.
df_Table2.describe()
# Out:
#                  Campaign Message type   Model
# count                  58           58      58
# unique                 58            2       7
# top     Sentra campaign 2  Near Market  Sentra
# freq                    1           37      25

# %%
#--Extracting summary statistics for numerical and categorical columns in table2.{But it is especially useful for numerical columns.}
df_Table2.describe(include = 'all')
# Out:
#                  Campaign Message type   Model
# count                  58           58      58
# unique                 58            2       7
# top     Sentra campaign 2  Near Market  Sentra
# freq                    1           37      25

# %%
#--Checking for the duplicates in table2.
df_Table2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# dtype: bool

# %%
#--Extracting the duplicate rows in table2.
df_Table2[df_Table1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Campaign, Message type, Model]
# Index: []

# %%
#--Removing the duplicate rows in table2.
df_Table2.drop_duplicates(inplace = True)

# %%
#--Extracting the null counts for all the columns in table2.
df_Table2.isnull().sum()
# Out:
# Campaign        0
# Message type    0
# Model           0
# dtype: int64

# %%
#--Extracting count of how many times each unique value appears in a specific column in table2.
for i in df_Table2.columns:
    print(i)
    print("__________________")
    print("__________________")
    print(df_Table2[i].value_counts())
    print("__________________")
# Out:
# Campaign
# __________________
# __________________
# Campaign
# Sentra campaign 2        1
# Sentra campaign 6        1
# shop at home             1
# Kicks campaign 2         1
# Kicks campaign 1         1
# Armada campaign 2        1
# Armada campaign 4        1
# Armada campaign 3        1
# Sentra campaign 11       1
# Sentra campaign 14       1
# Sentra campaign 20       1
# Sentra campaign 21       1
# Sentra campaign 9        1
# Sentra campaign 7        1
# Sentra campaign 12       1
# Sentra campaign 4        1
# Sentra campaign 19       1
# Sentra campaign 18       1
# Sentra campaign 22       1
# Sentra campaign 23       1
# Sentra campaign 25       1
# Sentra campaign 5        1
# Sentra campaign 13       1
# Sentra campaign 15       1
# Sentra campaign 8        1
# Sentra campaign 10       1
# Sentra campaign 24       1
# Sentra campaign 16       1
# Pathfinder campaign 4    1
# Pathfinder campaign 1    1
# Pathfinder campaign 2    1
# Kicks campaign 4         1
# ...

# %%
#--Extracting the minimum value in the Campaign column in table2.
df_Table2['Campaign'].min()
# Out:
# 'Altima campaign 1'

# %%
#--Extracting the maximum value in the Campaign column in table2.
df_Table2['Campaign'].max()
# Out:
# 'shop at home'

# %%
#--Extracting number of non-null counts for Campaign column in table2.
df_Table2['Campaign'].count()
# Out:
# 58

# %%
#--Extracting count of how many times each unique value appears in a Campaign column in table2.
df_Table2['Campaign'].value_counts()
# Out:
# Campaign
# Sentra campaign 2        1
# Sentra campaign 6        1
# shop at home             1
# Kicks campaign 2         1
# Kicks campaign 1         1
# Armada campaign 2        1
# Armada campaign 4        1
# Armada campaign 3        1
# Sentra campaign 11       1
# Sentra campaign 14       1
# Sentra campaign 20       1
# Sentra campaign 21       1
# Sentra campaign 9        1
# Sentra campaign 7        1
# Sentra campaign 12       1
# Sentra campaign 4        1
# Sentra campaign 19       1
# Sentra campaign 18       1
# Sentra campaign 22       1
# Sentra campaign 23       1
# Sentra campaign 25       1
# Sentra campaign 5        1
# Sentra campaign 13       1
# Sentra campaign 15       1
# Sentra campaign 8        1
# Sentra campaign 10       1
# Sentra campaign 24       1
# Sentra campaign 16       1
# Pathfinder campaign 4    1
# Pathfinder campaign 1    1
# Pathfinder campaign 2    1
# Kicks campaign 4         1
# Sentra campaign 3        1
# Sentra campaign 1        1
# ...

# %%
#--Extracting summary statistics for Campaign column in table2.
df_Table2['Campaign'].describe()
# Out:
# count                    58
# unique                   58
# top       Sentra campaign 2
# freq                      1
# Name: Campaign, dtype: object

# %%
#--Extracting unique values for Campaign column in table2.
df_Table2['Campaign'].unique()
# Out:
# array(['Sentra campaign 2', 'Sentra campaign 4', 'Sentra campaign 3',
#        'Sentra campaign 1', 'Altima campaign 1', 'Altima campaign 5',
#        'Altima campaign 4', 'Altima campaign 6', 'Kicks campaign 6',
#        'Kicks campaign 5', 'Rogue campaign 1', 'Rogue campaign 3',
#        'Rogue pre launch', 'Rogue campaign 5', 'Rogue campaign 4',
#        'Pathfinder campaign 3', 'Armada campaign 1',
#        'Pathfinder campaign 8', 'Pathfinder campaign 5',
#        'Pathfinder campaign 6', 'Pathfinder campaign 7',
#        'Altima campaign 3', 'Altima campaign 2', 'Altima campaign 7',
#        'Altima campaign 8', 'Rogue campaign 2', 'Kicks campaign 3',
#        'Kicks campaign 4', 'Pathfinder campaign 2',
#        'Pathfinder campaign 1', 'Pathfinder campaign 4', 'shop at home',
#        'Kicks campaign 2', 'Kicks campaign 1', 'Armada campaign 2',
#        'Armada campaign 4', 'Armada campaign 3', 'Sentra campaign 11',
# ...

# %%
#--Extracting number of unique values for Campaign column in table2.
df_Table2['Campaign'].nunique()
# Out:
# 58

# %%
#--Saving table2 to a excel file at the specified location on my system.
df_Table2.to_excel("D:\\Divya\\Python Classes\\Test Files\\Campaign_details2.xlsx")
